# %% [markdown]
# import numpy as np
# import pandas as pd

# %% [markdown]
# # Check the specs file

# %%
specs = pd.read_csv("Data/specs.csv")
print(specs.head())
# Out:
#    event_id                                               info  \
# 0  2b9272f4  The end of system-initiated feedback (Correct)...
# 1  df4fe8b6  The end of system-initiated feedback (Incorrec...
# 2  3babcb9b  The end of system-initiated instruction event ...
# 3  7f0836bf  The end of system-initiated instruction event ...
# 4  ab3136ba  The end of system-initiated instruction event ...
#
#                                                 args
# 0  [{"name":"game_time","type":"int","info":"mill...
# 1  [{"name":"game_time","type":"int","info":"mill...
# 2  [{"name":"game_time","type":"int","info":"mill...
# 3  [{"name":"game_time","type":"int","info":"mill...
# 4  [{"name":"game_time","type":"int","info":"mill...

# %%
specs['info'].head()
# Out:
# 0    The end of system-initiated feedback (Correct)...
# 1    The end of system-initiated feedback (Incorrec...
# 2    The end of system-initiated instruction event ...
# 3    The end of system-initiated instruction event ...
# 4    The end of system-initiated instruction event ...
# Name: info, dtype: object

# %% [markdown]
# # Check Train data

# %%
train = pd.read_csv('Data/train.csv')

# %%
train.count()
# Out:
# event_id           11341042
# game_session       11341042
# timestamp          11341042
# event_data         11341042
# installation_id    11341042
# event_count        11341042
# event_code         11341042
# game_time          11341042
# title              11341042
# type               11341042
# world              11341042
# dtype: int64

# %%
train.head()
# Out:
#    event_id      game_session                 timestamp  \
# 0  27253bdc  45bb1e1b6b50c07b  2019-09-06T17:53:46.937Z
# 1  27253bdc  17eeb7f223665f53  2019-09-06T17:54:17.519Z
# 2  77261ab5  0848ef14a8dc6892  2019-09-06T17:54:56.302Z
# 3  b2dba42b  0848ef14a8dc6892  2019-09-06T17:54:56.387Z
# 4  1bb5fbdb  0848ef14a8dc6892  2019-09-06T17:55:03.253Z
#
#                                           event_data installation_id  \
# 0             {"event_code": 2000, "event_count": 1}        0001e90f
# 1             {"event_code": 2000, "event_count": 1}        0001e90f
# 2  {"version":"1.0","event_count":1,"game_time":0...        0001e90f
# 3  {"description":"Let's build a sandcastle! Firs...        0001e90f
# 4  {"description":"Let's build a sandcastle! Firs...        0001e90f
#
#    event_count  event_code  game_time                          title  \
# 0            1        2000          0        Welcome to Lost Lagoon!
# 1            1        2000          0           Magma Peak - Level 1
# 2            1        2000          0  Sandcastle Builder (Activity)
# 3            2        3010         53  Sandcastle Builder (Activity)
# 4            3        3110       6972  Sandcastle Builder (Activity)
#
#        type      world
# 0      Clip       NONE
# 1      Clip  MAGMAPEAK
# 2  Activity  MAGMAPEAK
# 3  Activity  MAGMAPEAK
# 4  Activity  MAGMAPEAK

# %%
train.[train['installation_id'] == 'f1c21eda']
# Out:
#           event_id      game_session                 timestamp  \
# 10680753  27253bdc  b894736313219eae  2019-08-11T06:06:35.013Z
# 10680754  27253bdc  323eab9744201a71  2019-08-11T06:07:12.987Z
# 10680755  b7dc8128  36d3ea5b852c8fa8  2019-08-11T06:07:57.167Z
# 10680756  4b5efe37  36d3ea5b852c8fa8  2019-08-11T06:08:01.191Z
# 10680757  2c4e6db0  36d3ea5b852c8fa8  2019-08-11T06:08:03.487Z
# ...            ...               ...                       ...
# 10739736  bcceccc6  f1ae0f539891c710  2019-09-17T04:30:08.973Z
# 10739737  f28c589a  f1ae0f539891c710  2019-09-17T04:30:11.415Z
# 10739738  a1bbe385  f1ae0f539891c710  2019-09-17T04:30:16.334Z
# 10739739  28f975ea  f1ae0f539891c710  2019-09-17T04:30:17.783Z
# 10739740  f28c589a  f1ae0f539891c710  2019-09-17T04:30:17.786Z
#
#                                                  event_data installation_id  \
# 10680753             {"event_code": 2000, "event_count": 1}        f1c21eda
# 10680754             {"event_code": 2000, "event_count": 1}        f1c21eda
# 10680755  {"version":"1.0","round":0,"event_count":1,"ga...        f1c21eda
# 10680756  {"coordinates":{"x":566,"y":652,"stage_width":...        f1c21eda
# 10680757  {"houses":[5,2,1],"dinosaurs":[{"name":"petey"...        f1c21eda
# ...                                                     ...             ...
# 10739736  {"coordinates":{"x":2,"y":16,"stage_width":101...        f1c21eda
# 10739737  {"description":"I want you to land closer to t...        f1c21eda
# 10739738  {"description":"I want you to land closer to t...        f1c21eda
# 10739739  {"distance":3,"dinosaur":"tiny","target_distan...        f1c21eda
# 10739740  {"description":"You moved your dinosaur Three ...        f1c21eda
#
#           event_count  event_code  game_time                    title  type  \
# 10680753            1        2000          0  Welcome to Lost Lagoon!  Clip
# 10680754            1        2000          0  Tree Top City - Level 1  Clip
# 10680755            1        2000          0         All Star Sorting  Game
# 10680756            2        4010       5037         All Star Sorting  Game
# 10680757            3        2020       7170         All Star Sorting  Game
# ...               ...         ...        ...                      ...   ...
# 10739736           32        4070      83330                 Air Show  Game
# 10739737           33        3010      85817                 Air Show  Game
# 10739738           34        3110      90737                 Air Show  Game
# 10739739           35        4020      92144                 Air Show  Game
# 10739740           36        3010      92144                 Air Show  Game
#
#                 world
# 10680753         NONE
# 10680754  TREETOPCITY
# 10680755  TREETOPCITY
# 10680756  TREETOPCITY
# 10680757  TREETOPCITY
# ...               ...
# 10739736  TREETOPCITY
# 10739737  TREETOPCITY
# 10739738  TREETOPCITY
# 10739739  TREETOPCITY
# 10739740  TREETOPCITY
#
# [58988 rows x 11 columns]

# %%
train.count()
# Out:
# event_id           11341042
# game_session       11341042
# timestamp          11341042
# event_data         11341042
# installation_id    11341042
# event_count        11341042
# event_code         11341042
# game_time          11341042
# title              11341042
# type               11341042
# world              11341042
# dtype: int64

# %% [markdown]
# # Train label

# %%
label = pd.read_csv("Data/train_labels.csv")

# %%
label.head()
# Out:
#        game_session installation_id                         title  \
# 0  6bdf9623adc94d89        0006a69f  Mushroom Sorter (Assessment)
# 1  77b8ee947eb84b4e        0006a69f    Bird Measurer (Assessment)
# 2  901acc108f55a5a1        0006a69f  Mushroom Sorter (Assessment)
# 3  9501794defd84e4d        0006a69f  Mushroom Sorter (Assessment)
# 4  a9ef3ecb3d1acc6a        0006a69f    Bird Measurer (Assessment)
#
#    num_correct  num_incorrect  accuracy  accuracy_group
# 0            1              0       1.0               3
# 1            0             11       0.0               0
# 2            1              0       1.0               3
# 3            1              1       0.5               2
# 4            1              0       1.0               3

# %%
len(label['installation_id'].unique())
# Out:
# 3614

# %%
data = pd.merge(train,label,on='game_session')

# %%
data
# Out:
#         event_id      game_session                 timestamp  \
# 0       3bfd1a65  901acc108f55a5a1  2019-08-06T05:22:01.344Z
# 1       db02c830  901acc108f55a5a1  2019-08-06T05:22:01.400Z
# 2       a1e4395d  901acc108f55a5a1  2019-08-06T05:22:01.403Z
# 3       a52b92d5  901acc108f55a5a1  2019-08-06T05:22:05.242Z
# 4       a1e4395d  901acc108f55a5a1  2019-08-06T05:22:05.244Z
# ...          ...               ...                       ...
# 865442  28520915  5448d652309a6324  2019-09-22T02:07:27.562Z
# 865443  91561152  5448d652309a6324  2019-09-22T02:07:27.562Z
# 865444  d3268efa  5448d652309a6324  2019-09-22T02:07:27.566Z
# 865445  b5053438  5448d652309a6324  2019-09-22T02:07:28.311Z
# 865446  2b058fe3  5448d652309a6324  2019-09-22T02:07:31.963Z
#
#                                                event_data installation_id_x  \
# 0       {"version":"1.0","event_count":1,"game_time":0...          0006a69f
# 1       {"event_count":2,"game_time":37,"event_code":2...          0006a69f
# 2       {"description":"Pull three mushrooms out of th...          0006a69f
# 3       {"description":"Pull three mushrooms out of th...          0006a69f
# 4       {"description":"To pick a mushroom, pull it ou...          0006a69f
# ...                                                   ...               ...
# 865442  {"misses":1,"prompt":"holds least","mode":"sel...          ffeb0b1b
# 865443  {"bucket":1,"buckets_placed":[3,1,2],"target_b...          ffeb0b1b
# 865444  {"description":"Awesome.","identifier":"Dot_Aw...          ffeb0b1b
# 865445  {"description":"Awesome.","identifier":"Dot_Aw...          ffeb0b1b
# 865446  {"session_duration":71511,"event_count":61,"ga...          ffeb0b1b
#
#         event_count  event_code  game_time                       title_x  \
# 0                 1        2000          0  Mushroom Sorter (Assessment)
# 1                 2        2025         37  Mushroom Sorter (Assessment)
# 2                 3        3010         37  Mushroom Sorter (Assessment)
# 3                 4        3110       3901  Mushroom Sorter (Assessment)
# 4                 5        3010       3901  Mushroom Sorter (Assessment)
# ...             ...         ...        ...                           ...
# 865442           58        2030      67094  Cauldron Filler (Assessment)
# 865443           57        4025      67094  Cauldron Filler (Assessment)
# 865444           59        3021      67094  Cauldron Filler (Assessment)
# 865445           60        3121      67847  Cauldron Filler (Assessment)
# 865446           61        2010      71511  Cauldron Filler (Assessment)
#
#               type        world installation_id_y  \
# 0       Assessment  TREETOPCITY          0006a69f
# 1       Assessment  TREETOPCITY          0006a69f
# 2       Assessment  TREETOPCITY          0006a69f
# 3       Assessment  TREETOPCITY          0006a69f
# 4       Assessment  TREETOPCITY          0006a69f
# ...            ...          ...               ...
# 865442  Assessment    MAGMAPEAK          ffeb0b1b
# 865443  Assessment    MAGMAPEAK          ffeb0b1b
# 865444  Assessment    MAGMAPEAK          ffeb0b1b
# 865445  Assessment    MAGMAPEAK          ffeb0b1b
# 865446  Assessment    MAGMAPEAK          ffeb0b1b
#
#                              title_y  num_correct  num_incorrect  accuracy  \
# 0       Mushroom Sorter (Assessment)            1              0  1.000000
# 1       Mushroom Sorter (Assessment)            1              0  1.000000
# 2       Mushroom Sorter (Assessment)            1              0  1.000000
# 3       Mushroom Sorter (Assessment)            1              0  1.000000
# 4       Mushroom Sorter (Assessment)            1              0  1.000000
# ...                              ...          ...            ...       ...
# 865442  Cauldron Filler (Assessment)            1              2  0.333333
# 865443  Cauldron Filler (Assessment)            1              2  0.333333
# 865444  Cauldron Filler (Assessment)            1              2  0.333333
# 865445  Cauldron Filler (Assessment)            1              2  0.333333
# 865446  Cauldron Filler (Assessment)            1              2  0.333333
#
#         accuracy_group
# 0                    3
# 1                    3
# 2                    3
# 3                    3
# 4                    3
# ...                ...
# 865442               1
# 865443               1
# 865444               1
# 865445               1
# 865446               1
#
# [865447 rows x 17 columns]

# %%
data['type'].value_counts()
# Out:
# Assessment    865447
# Name: type, dtype: int64

# %% [markdown]
# # Sample submission

# %%
sample_submission = pd.read_csv("Data/sample_submission.csv")

# %%
sample_submission.head()
# Out:
#   installation_id  accuracy_group
# 0        00abaee7               3
# 1        01242218               3
# 2        017c5718               3
# 3        01a44906               3
# 4        01bc6cb6               3

# %% [markdown]
# # Test

# %%
test = pd.read_csv("Data/test.csv")

# %%
test.head()
# Out:
#    event_id      game_session                 timestamp  \
# 0  27253bdc  0ea9ecc81a565215  2019-09-10T16:50:24.910Z
# 1  27253bdc  c1ea43d8b8261d27  2019-09-10T16:50:55.503Z
# 2  27253bdc  7ed86c6b72e725e2  2019-09-10T16:51:51.805Z
# 3  27253bdc  7e516ace50e7fe67  2019-09-10T16:53:12.825Z
# 4  7d093bf9  a022c3f60ba547e7  2019-09-10T16:54:12.115Z
#
#                                           event_data installation_id  \
# 0             {"event_code": 2000, "event_count": 1}        00abaee7
# 1             {"event_code": 2000, "event_count": 1}        00abaee7
# 2             {"event_code": 2000, "event_count": 1}        00abaee7
# 3             {"event_code": 2000, "event_count": 1}        00abaee7
# 4  {"version":"1.0","round":0,"event_count":1,"ga...        00abaee7
#
#    event_count  event_code  game_time                    title  type  \
# 0            1        2000          0  Welcome to Lost Lagoon!  Clip
# 1            1        2000          0     Magma Peak - Level 1  Clip
# 2            1        2000          0     Magma Peak - Level 2  Clip
# 3            1        2000          0  Crystal Caves - Level 1  Clip
# 4            1        2000          0                Chow Time  Game
#
#           world
# 0          NONE
# 1     MAGMAPEAK
# 2     MAGMAPEAK
# 3  CRYSTALCAVES
# 4  CRYSTALCAVES
